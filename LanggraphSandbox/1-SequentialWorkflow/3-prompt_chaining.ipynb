# %%
from pathlib import Path
from typing import TypedDict
from dotenv import load_dotenv
from IPython.display import Markdown, display
from langgraph.graph import StateGraph, START, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

from rich.console import Console
from rich.pretty import Pretty
from rich.theme import Theme
from rich.panel import Panel
from rich.markdown import Markdown


theme = Theme(
    {
        "json.key": "#c1a2ff",
        "json.string": "#FCCEA1",
        "json.number": "#A1C4FD",
        "json.boolean": "#A6F5D8",
        "json.null": "#ffb3ba",
    }
)

console = Console(
    theme=theme,
    force_terminal=True,
    force_jupyter=False,
    color_system="truecolor",
)

# %%
# get LLM
def get_model(model="gemini-2.5-flash", temperature=0.7, max_output_tokens=8000):
    model = ChatGoogleGenerativeAI(model=model, temperature=temperature, max_output_tokens=max_output_tokens)
    parser = StrOutputParser()

    chain = model | parser
    return chain


model = get_model()

# %%
# state
class BlogState(TypedDict):
    blog_topic: str
    blog_outline: str
    blog_content: str
    blog_summary: str

# %%
# topic generator
def generate_blog_topic(state: BlogState):
    prompt = ChatPromptTemplate(
        [
            (
                "system",
                "You are an astronomy research scout. Output exactly one high-interest trending astronomy topic as a single word or a strict compound noun. Do not include introductory text, punctuation, or formatting.",
            ),
            ("user", "Provide one trending astronomy topic."),
        ]
    )

    chain = prompt | model
    state["blog_topic"] = chain.invoke({})

    return state

# %%
# outline generator
def generate_blog_outline(state: BlogState) -> BlogState:
    prompt = ChatPromptTemplate(
        [
            (
                "system",
                "You are an expert technical editor. Generate a clear, structured Markdown outline for a deep-dive blog post based on the provided topic. Ensure a logical progression from introduction to technical breakdown and conclusion.",
            ),
            ("user", "Topic: {topic}"),
        ]
    )

    chain = prompt | model
    state["blog_outline"] = chain.invoke({"topic": state["blog_topic"]})
    return state

# %%
# blog generator
def generate_blog_content(state: BlogState) -> BlogState:
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are an authoritative science communicator. Expand the provided outline into a comprehensive, engaging, and scientifically accurate blog post. Use clear Markdown headers, bold text for key terms, and maintain an informative yet accessible tone.",
            ),
            ("user", "Topic: {topic}\n\nOutline:\n{outline}"),
        ]
    )

    chain = prompt | model
    state["blog_content"] = chain.invoke(
        {
            "topic": state["blog_topic"],
            "outline": state["blog_outline"],
        }
    )
    return state

# %%
# summary generator
def generate_blog_summary(state: BlogState) -> BlogState:
    prompt = ChatPromptTemplate.from_messages(
        [
            (
                "system",
                "You are an executive editor. Create a dense, highly informative 3-4 sentence summary of the provided blog content. Capture the core thesis, primary scientific insights, and final conclusion without using fluff or introductory phrases.",
            ),
            ("user", "Content:\n{content}"),
        ]
    )

    chain = prompt | model
    state["blog_summary"] = chain.invoke({"content": state["blog_content"]})
    return state

# %%
# init graph
graph = StateGraph(BlogState)

# %%
# add nodes
graph.add_node("generate_blog_topic", generate_blog_topic)
graph.add_node("generate_blog_outline", generate_blog_outline)
graph.add_node("generate_blog_content", generate_blog_content)
graph.add_node("generate_blog_summary", generate_blog_summary)

# %%
# add edges
graph.add_edge(START, "generate_blog_topic")
graph.add_edge("generate_blog_topic", "generate_blog_outline")
graph.add_edge("generate_blog_outline", "generate_blog_content")
graph.add_edge("generate_blog_content", "generate_blog_summary")
graph.add_edge("generate_blog_summary", END)

# %%
# compilation
workflow = graph.compile()
workflow

# %%
# execution
final_state = workflow.invoke({})

# %%
console.print(Pretty(final_state["blog_topic"], justify="center"))
# Out:
#                                   'Exoplanets'

# %%
Path("files").mkdir(exist_ok=True)

with open("./files/1-outline.md", "w") as f:
    f.write(final_state["blog_outline"])


content = Path("files/1-outline.md").read_text()

console.print(
    Panel(
        Markdown(content),
        title="Outline",
        border_style="#6CFCCE",
    )
)
# Out:
# ╭────────────────────────────────── Outline ───────────────────────────────────╮
# │ Here's a clear, structured Markdown outline for a deep-dive blog post on     │
# │ exoplanets:                                                                  │
# │                                                                              │
# │ ---------------------------------------------------------------------------- │
# │                                                                              │
# │           Deep Dive: Unveiling the Worlds Beyond Our Solar System            │
# │                                                                              │
# │ I. Introduction: A Universe of Other Worlds                                  │
# │                                                                              │
# │  • A. The Age-Old Question: Are we alone? The human fascination with other   │
# │    planets.                                                                  │
# │  • B. Defining Exoplanets: What they are (planets orbiting stars other than  │
# │    our Sun).                                                                 │
# │  • C. A Brief History of Discovery: From theoretical concept to concrete     │
# │    reality (pre-1990s vs. post-1995 explosion).                              │
# │  • D. The Significance of Exoplanet Research: Understanding planet           │
# │    formation, the prevalence of life, and our place in the cosmos.           │
# │  • E. Post Thesis: This post will explore the methods of exoplanet           │
# │    detection, the incredible diversity of these worlds, and the ongoing      │
# │    quest to find signs of life.                                              │
# │                                                                              │
# │ II. What Are Exoplanets? A Foundational Understanding                        │
# │                                                                              │
# │  • A. Core Definition: Planets orbiting stars outside our solar system.      │
# │  • B. Distinctions:                                                          │
# │     • Planets vs. Brown Dwarfs (mass boundary).                              │
# │     • Bound vs. Rogue Planets (gravitational attachment).                    │
# │  • C. Why They Matter:                                                       │
# │     • Testing theories of planetary formation and evolution.                 │
# │     • Understanding the conditions for life.                                 │
# │     • Providing context for our own solar system.                            │
# │                                                                              │
# │ III. The Art of Detection: How We Find the Unseen                            │
# │                                                                              │
# │  • A. Introduction to Indirect Detection: The challenges of seeing faint     │
# │    planets next to bright stars.                                             │
# │  • B. Radial Velocity Method (Doppler Spectroscopy):                         │
# │     • 1. Principle: Detecting the "wobble" of a star caused by an orbiting   │
# │       planet's gravitational pull.                                           │
# │     • 2. How it Works: Measuring the Doppler shift (redshift/blueshift) in   │
# │       the star's light spectrum.                                             │
# │     • 3. Strengths: Can determine minimum mass and orbital period.           │
# │     • 4. Limitations: Favors massive, close-in planets; doesn't give true    │
# │       mass without inclination; difficult for smaller planets.               │
# │  • C. Transit Photometry Method:                                             │
# │     • 1. Principle: Measuring the slight dimming of a star's light as a      │
# │       planet passes in front of it (transits).                               │
# │     • 2. How it Works: Analyzing the star's light curve for periodic dips.   │
# │     • 3. Strengths: Can determine planet radius, orbital period, and         │
# │       potential for atmospheric studies (transit spectroscopy).              │
# │     • 4. Key Missions: Kepler, TESS.                                         │
# │     • 5. Limitations: Requires precise orbital alignment; only detects       │
# │       planets that transit.                                                  │
# │  • D. Direct Imaging:                                                        │
# │     • 1. Principle: Directly observing the exoplanet's light, separate from  │
# │       its star.                                                              │
# │     • 2. Challenges: Extreme brightness contrast between star and planet;    │
# │       angular resolution.                                                    │
# │     • 3. Technologies: Coronagraphs, adaptive optics, starshades (future).   │
# │     • 4. Strengths: Direct observation, potential for detailed atmospheric   │
# │       characterization.                                                      │
# │     • 5. Limitations: Favors large, hot, distant planets.                    │
# │  • E. Gravitational Microlensing:                                            │
# │     • 1. Principle: Using the gravitational field of a foreground star and   │
# │       its planet to magnify light from a background star.                    │
# │     • 2. How it Works: Detecting a unique brightening pattern of the         │
# │       background star.                                                       │
# │     • 3. Strengths: Can detect low-mass planets at great distances,          │
# │       including rogue planets.                                               │
# │     • 4. Limitations: One-time event; difficult to confirm or re-observe.    │
# │  • F. Astrometry (Brief Mention): Measuring tiny shifts in a star's position │
# │    on the sky.                                                               │
# │                                                                              │
# │ IV. A Menagerie of Worlds: The Diversity of Exoplanets                       │
# │                                                                              │
# │  • A. Hot Jupiters: Gas giants orbiting extremely close to their stars.      │
# │  • B. Super-Earths & Mini-Neptunes: Planets larger than Earth but smaller    │
# │    than Neptune, with diverse compositions.                                  │
# │  • C. Ocean Worlds & Water Worlds: Planets potentially covered entirely in   │
# │    deep oceans.                                                              │
# │  • D. Lava Worlds: Planets tidally locked and extremely hot, with molten     │
# │    surfaces.                                                                 │
# │  • E. Eyeball Planets: Tidally locked planets with one side perpetually      │
# │    facing their star, creating extreme temperature gradients.                │
# │  • F. Rogue Planets: Planets ejected from their star systems, drifting       │
# │    through interstellar space.                                               │
# │  • G. Habitable Zone Planets: Worlds within the "Goldilocks zone" where      │
# │    liquid water could exist.                                                 │
# │                                                                              │
# │ V. The Ultimate Quest: Searching for Life Beyond Earth                       │
# │                                                                              │
# │  • A. The Habitable Zone (Goldilocks Zone):                                  │
# │     • 1. Definition: The region around a star where temperatures allow for   │
# │       liquid water on a planet's surface.                                    │
# │     • 2. Factors Influencing the Zone: Star type (spectral class), planet    │
# │       mass, atmospheric composition.                                         │
# │  • B. Biosignatures:                                                         │
# │     • 1. What They Are: Chemical evidence of life (e.g., oxygen, methane,    │
# │       water vapor, ozone).                                                   │
# │     • 2. How We Detect Them: Transit spectroscopy (analyzing starlight       │
# │       filtered through a planet's atmosphere).                               │
# │  • C. Technosignatures (Brief Mention): Evidence of advanced technology      │
# │    (e.g., artificial signals, industrial pollution).                         │
# │  • D. Key Targets: TRAPPIST-1 system, Proxima Centauri b, K2-18b, and more.  │
# │                                                                              │
# │ VI. The Future of Exoplanet Research: A New Era of Discovery                 │
# │                                                                              │
# │  • A. Current & Upcoming Missions:                                           │
# │     • 1. James Webb Space Telescope (JWST): Unprecedented atmospheric        │
# │       characterization, direct imaging.                                      │
# │     • 2. ARIEL (Atmospheric Remote-sensing Infrared Exoplanet Large-survey): │
# │       Dedicated to studying exoplanet atmospheres.                           │
# │     • 3. PLATO (PLAnetary Transits and Oscillations of stars): Focusing on   │
# │       finding Earth-like planets in habitable zones.                         │
# │     • 4. Nancy Grace Roman Space Telescope: Microlensing and coronagraphy    │
# │       for exoplanet imaging.                                                 │
# │  • B. Technological Advancements:                                            │
# │     • 1. Next-Generation Adaptive Optics: Sharper direct imaging.            │
# │     • 2. Starshades/Occulters: Blocking starlight to enable direct imaging   │
# │       of Earth-like planets.                                                 │
# │     • 3. Advanced Data Analysis: AI and machine learning to sift through     │
# │       vast datasets.                                                         │
# │  • C. Key Unanswered Questions:                                              │
# │     • How common is life in the universe?                                    │
# │     • What are the full range of planetary system architectures?             │
# │     • Can we find a true "Earth 2.0"?                                        │
# │                                                                              │
# │ VII. Conclusion: Our Place in a Populated Cosmos                             │
# │                                                                              │
# │  • A. Recap: The rapid evolution of exoplanet science, from initial          │
# │    discovery to detailed characterization.                                   │
# │  • B. The Profound Impact: Exoplanets reshape our understanding of planetary │
# │    formation and the potential for life.                                     │
# │  • C. The Journey Continues: The exciting prospects for future discoveries   │
# │    and the ongoing search for answers.                                       │
# │  • D. Final Thought: The universe is far richer and more diverse than we     │
# │    ever imagined, beckoning us to continue exploring.                        │
# │                                                                              │
# │ ---------------------------------------------------------------------------- │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
with open("./files/2-blog_content.md", "w") as f:
    f.write(final_state["blog_content"])

content = Path("files/2-blog_content.md").read_text()

console.print(
    Panel(
        Markdown(content),
        title="Content",
        border_style="#6CFCCE",
    )
)
# Out:
# ╭────────────────────────────────── Content ───────────────────────────────────╮
# │           Deep Dive: Unveiling the Worlds Beyond Our Solar System            │
# │                                                                              │
# │ I. Introduction: A Universe of Other Worlds                                  │
# │                                                                              │
# │ For millennia, humanity has gazed at the stars, pondering a fundamental      │
# │ question: Are we alone? This age-old fascination with celestial bodies       │
# │ beyond our own solar system has driven poets, philosophers, and scientists   │
# │ alike. For most of history, the idea of planets orbiting distant stars was   │
# │ pure speculation, a tantalizing "what if."                                   │
# │                                                                              │
# │ Today, this question is no longer confined to the realm of science fiction.  │
# │ We live in an extraordinary era where the existence of exoplanets—planets    │
# │ orbiting stars other than our Sun—is not just confirmed, but commonplace.    │
# │ From the first confirmed discovery in 1995 (51 Pegasi b) to the thousands we │
# │ know today, the field of exoplanet research has exploded, transforming our   │
# │ understanding of the cosmos.                                                 │
# │                                                                              │
# │ The significance of exoplanet research is profound. It's not merely about    │
# │ tallying new worlds; it's about unraveling the mysteries of planet           │
# │ formation, understanding the prevalence of life in the universe, and         │
# │ ultimately, contextualizing our own place within a vast and diverse cosmos.  │
# │ This post will journey through the ingenious methods we use to detect these  │
# │ hidden worlds, marvel at the incredible diversity they exhibit, and explore  │
# │ the ongoing quest to find the ultimate prize: signs of life beyond Earth.    │
# │                                                                              │
# │ II. What Are Exoplanets? A Foundational Understanding                        │
# │                                                                              │
# │ At its core, an exoplanet is simply a planet that orbits a star outside of   │
# │ our solar system. While this definition seems straightforward, there are     │
# │ important distinctions to make.                                              │
# │                                                                              │
# │ Firstly, exoplanets are distinct from brown dwarfs, which are often called   │
# │ "failed stars." Brown dwarfs are celestial objects with masses between that  │
# │ of a giant planet like Jupiter and a small star. They are massive enough to  │
# │ fuse deuterium (a heavy isotope of hydrogen) but not regular hydrogen,       │
# │ unlike true stars. The current widely accepted boundary between a planet and │
# │ a brown dwarf is approximately 13 Jupiter masses – objects above this are    │
# │ generally considered brown dwarfs.                                           │
# │                                                                              │
# │ Secondly, most exoplanets are bound to a star by gravity, forming a          │
# │ planetary system. However, recent discoveries have revealed the existence of │
# │ rogue planets (also known as interstellar or free-floating planets). These   │
# │ are planets that have been ejected from their birth systems and now wander   │
# │ through interstellar space, unbound to any star.                             │
# │                                                                              │
# │ Why do these distinctions and the study of exoplanets matter so much? They   │
# │ are crucial for testing and refining our theories of planetary formation and │
# │ evolution. By observing a multitude of planetary systems, we can see which   │
# │ models hold up and which need revision. Exoplanets also provide invaluable   │
# │ insights into the conditions necessary for life to arise and thrive, guiding │
# │ our search for habitable worlds. Finally, understanding the sheer variety of │
# │ exoplanetary systems provides a vital context for our own solar system,      │
# │ helping us appreciate its unique characteristics and commonalities within    │
# │ the broader galactic neighborhood.                                           │
# │                                                                              │
# │ III. The Art of Detection: How We Find the Unseen                            │
# │                                                                              │
# │ Detecting exoplanets is an extraordinary feat, akin to spotting a firefly    │
# │ next to a lighthouse from hundreds of miles away. Stars are immensely        │
# │ bright, and their orbiting planets are tiny, faint, and often incredibly     │
# │ close to their host star from our perspective. This makes direct imaging     │
# │ extremely challenging, leading scientists to develop ingenious indirect      │
# │ detection methods.                                                           │
# │                                                                              │
# │ A. Introduction to Indirect Detection                                        │
# │                                                                              │
# │ Since most exoplanets are too small and dim to be seen directly, astronomers │
# │ primarily rely on observing the subtle effects a planet has on its host star │
# │ or the light from a background star. These indirect methods have             │
# │ revolutionized our ability to find these elusive worlds.                     │
# │                                                                              │
# │ B. Radial Velocity Method (Doppler Spectroscopy)                             │
# │                                                                              │
# │ The radial velocity method, also known as Doppler spectroscopy, was one of   │
# │ the first successful techniques.                                             │
# │                                                                              │
# │  1 Principle: It detects the tiny "wobble" of a star caused by the           │
# │    gravitational tug of an orbiting planet. Just as a planet orbits a star,  │
# │    the star also orbits a common center of mass, albeit subtly.              │
# │  2 How it Works: As the star wobbles, it moves slightly towards and away     │
# │    from Earth. This motion causes a Doppler shift in the star's light: light │
# │    is blueshifted when the star moves towards us and redshifted when it      │
# │    moves away. By precisely measuring these shifts in the star's spectral    │
# │    lines, astronomers can infer the presence and mass of an orbiting planet. │
# │  3 Strengths: This method can determine a planet's minimum mass and its      │
# │    orbital period.                                                           │
# │  4 Limitations: It favors massive, close-in planets that exert a stronger    │
# │    gravitational pull. Without knowing the planet's orbital inclination (its │
# │    tilt relative to our line of sight), we can only determine a minimum      │
# │    mass, not the true mass. It's also difficult for smaller, Earth-like      │
# │    planets.                                                                  │
# │                                                                              │
# │ C. Transit Photometry Method                                                 │
# │                                                                              │
# │ The transit photometry method has been responsible for the discovery of the  │
# │ vast majority of known exoplanets, thanks to missions like Kepler and TESS.  │
# │                                                                              │
# │  1 Principle: This method measures the slight, periodic dimming of a star's  │
# │    light as a planet passes directly in front of it (a transit) from our     │
# │    perspective.                                                              │
# │  2 How it Works: Astronomers monitor a star's light curve—a graph of its     │
# │    brightness over time. A characteristic, periodic dip in brightness        │
# │    indicates a transiting planet. The depth of the dip reveals the planet's  │
# │    size relative to the star, while the duration of the dip helps determine  │
# │    its orbital period.                                                       │
# │  3 Strengths: This method can directly determine the planet's radius and     │
# │    orbital period. Crucially, during a transit, a tiny fraction of the       │
# │    star's light passes through the planet's atmosphere, allowing for transit │
# │    spectroscopy to study its atmospheric composition.                        │
# │  4 Key Missions: NASA's Kepler Space Telescope (now retired) was a pioneer,  │
# │    discovering thousands of exoplanets. Its successor, the Transiting        │
# │    Exoplanet Survey Satellite (TESS), continues to find thousands of new     │
# │    worlds, focusing on nearby, bright stars.                                 │
# │  5 Limitations: This method requires a precise orbital alignment where the   │
# │    planet's orbit is edge-on to our line of sight. This means we only detect │
# │    a small fraction of all existing planets.                                 │
# │                                                                              │
# │ D. Direct Imaging                                                            │
# │                                                                              │
# │ Direct imaging is the most intuitive method: actually seeing the exoplanet.  │
# │ While challenging, it offers the most detailed information.                  │
# │                                                                              │
# │  1 Principle: Directly observing the exoplanet's light, separate from its    │
# │    much brighter host star.                                                  │
# │  2 Challenges: The extreme brightness contrast between a star and its planet │
# │    (often billions of times brighter for the star) and the tiny angular      │
# │    separation between them make this incredibly difficult.                   │
# │  3 Technologies: To overcome these hurdles, astronomers use advanced         │
# │    techniques like coronagraphs (which block out the star's light), adaptive │
# │    optics (which correct for atmospheric distortions), and future concepts   │
# │    like starshades (external spacecraft that block starlight before it       │
# │    reaches the telescope).                                                   │
# │  4 Strengths: Direct observation allows for unique insights into the         │
# │    planet's atmosphere, composition, and even weather patterns. It's         │
# │    currently the best way for detailed atmospheric characterization.         │
# │  5 Limitations: It currently favors large, hot, and relatively young planets │
# │    that are far from their stars, as these are brighter (due to residual     │
# │    heat from formation) and easier to resolve.                               │
# │                                                                              │
# │ E. Gravitational Microlensing                                                │
# │                                                                              │
# │ Gravitational microlensing uses a cosmic phenomenon predicted by Einstein's  │
# │ theory of relativity.                                                        │
# │                                                                              │
# │  1 Principle: It relies on the gravitational field of a foreground star (and │
# │    any planets it might host) to magnify and distort the light from a more   │
# │    distant, background star.                                                 │
# │  2 How it Works: As the foreground star system passes precisely in front of  │
# │    a background star, its gravity acts like a lens, temporarily brightening  │
# │    the background star's light. If the foreground star has a planet, that    │
# │    planet's gravity creates an additional, shorter-duration brightening      │
# │    "spike" on top of the star's signal.                                      │
# │  3 Strengths: This method is powerful for detecting low-mass planets,        │
# │    including Earth-mass planets, at great distances from their stars, and    │
# │    even rogue planets unbound to any star.                                   │
# │  4 Limitations: It's a one-time, chance alignment event, making it difficult │
# │    to confirm or re-observe a discovery.                                     │
# │                                                                              │
# │ F. Astrometry (Brief Mention)                                                │
# │                                                                              │
# │ Astrometry is a precise method that measures the tiny, periodic shifts in a  │
# │ star's position on the sky caused by the gravitational tug of an orbiting    │
# │ planet. While conceptually similar to radial velocity, it measures the       │
# │ side-to-side wobble rather than the back-and-forth motion. It requires       │
# │ extremely precise measurements and has yielded fewer discoveries than other  │
# │ methods but is gaining traction with missions like Gaia.                     │
# │                                                                              │
# │ IV. A Menagerie of Worlds: The Diversity of Exoplanets                       │
# │                                                                              │
# │ The thousands of exoplanets discovered so far have shattered our             │
# │ preconceived notions of planetary systems. Our solar system, once thought to │
# │ be typical, now appears to be just one of many possible configurations. The  │
# │ cosmos is home to a truly astounding menagerie of worlds:                    │
# │                                                                              │
# │ A. Hot Jupiters                                                              │
# │                                                                              │
# │ These are gas giants similar in mass to Jupiter, but they orbit incredibly   │
# │ close to their host stars, often completing an orbit in just a few Earth     │
# │ days. Their proximity to their stars results in scorching temperatures,      │
# │ hence the name Hot Jupiters. Their existence challenged early planet         │
# │ formation theories, suggesting that planets can migrate inward from their    │
# │ birthplaces.                                                                 │
# │                                                                              │
# │ B. Super-Earths & Mini-Neptunes                                              │
# │                                                                              │
# │ These are among the most common types of exoplanets. Super-Earths are        │
# │ planets larger than Earth but smaller than Neptune, with masses typically    │
# │ 2-10 times that of Earth. Their compositions vary wildly, from rocky worlds  │
# │ to water-rich planets. Mini-Neptunes are also between Earth and Neptune in   │
# │ size but are thought to have thick hydrogen-helium atmospheres, similar to   │
# │ Neptune but scaled down. Many of these worlds have no direct analogue in our │
# │ solar system.                                                                │
# │                                                                              │
# │ C. Ocean Worlds & Water Worlds                                               │
# │                                                                              │
# │ Some exoplanets are theorized to be entirely covered in deep, global oceans, │
# │ earning them the moniker Ocean Worlds or Water Worlds. These planets could   │
# │ have formed further out in their stellar systems, accumulating vast amounts  │
# │ of ice, and then migrated inward to a region where that ice melted into      │
# │ liquid water. The potential for life in such environments is a subject of    │
# │ intense scientific interest.                                                 │
# │                                                                              │
# │ D. Lava Worlds                                                               │
# │                                                                              │
# │ Imagine a planet so close to its star that its surface is a churning sea of  │
# │ molten rock. Lava Worlds are tidally locked (always showing the same face to │
# │ their star), with one side perpetually baked by extreme heat, creating vast  │
# │ oceans of lava, while the other side remains in eternal twilight or          │
# │ darkness.                                                                    │
# │                                                                              │
# │ E. Eyeball Planets                                                           │
# │                                                                              │
# │ Another fascinating type of tidally locked world is the Eyeball Planet.      │
# │ These planets, often found in the habitable zones of cooler stars (like red  │
# │ dwarfs), have one side perpetually facing their star, leading to extreme     │
# │ temperature gradients. The "eyeball" effect comes from a potential ice cap   │
# │ on the dark side, a liquid ocean or landmass in the temperate zone, and a    │
# │ superheated, dry "pupil" on the star-facing side.                            │
# │                                                                              │
# │ F. Rogue Planets                                                             │
# │                                                                              │
# │ As mentioned earlier, Rogue Planets are worlds that have been                │
# │ gravitationally ejected from their birth systems. They drift through the     │
# │ cold, dark expanse of interstellar space, unattached to any star. While      │
# │ seemingly inhospitable, some theories suggest that if they possess thick     │
# │ atmospheres or internal heat sources (like geothermal activity), they could  │
# │ potentially harbor subsurface oceans or even life.                           │
# │                                                                              │
# │ G. Habitable Zone Planets                                                    │
# │                                                                              │
# │ Perhaps the most exciting category are planets found within the habitable    │
# │ zone (often called the "Goldilocks zone") of their stars. These are worlds   │
# │ where conditions could allow for liquid water to exist on their surface, a   │
# │ key ingredient for life as we know it. While being in the habitable zone     │
# │ doesn't guarantee habitability, it marks them as prime targets in the search │
# │ for extraterrestrial life.                                                   │
# │                                                                              │
# │ V. The Ultimate Quest: Searching for Life Beyond Earth                       │
# │                                                                              │
# │ The discovery of thousands of exoplanets has dramatically shifted the focus  │
# │ of astrobiology. The question is no longer if other planets exist, but how   │
# │ many of them could potentially harbor life.                                  │
# │                                                                              │
# │ A. The Habitable Zone (Goldilocks Zone)                                      │
# │                                                                              │
# │  1 Definition: The habitable zone is the region around a star where          │
# │    conditions are just right for liquid water to exist on a planet's         │
# │    surface. It's not too hot (water evaporates) and not too cold (water      │
# │    freezes solid).                                                           │
# │  2 Factors Influencing the Zone: The size and location of this zone are      │
# │    influenced by several factors:                                            │
# │     • Star Type (Spectral Class): Hotter, more massive stars have wider      │
# │       habitable zones further out, while cooler, smaller stars (like red     │
# │       dwarfs) have narrower habitable zones much closer in.                  │
# │     • Planet Mass & Atmosphere: A planet's mass affects its ability to       │
# │       retain an atmosphere, which in turn influences surface temperature and │
# │       the presence of liquid water. A thick atmosphere can trap heat,        │
# │       expanding the inner edge of the habitable zone.                        │
# │     • Orbital Eccentricity: A highly elliptical orbit can take a planet in   │
# │       and out of the habitable zone, making sustained liquid water           │
# │       challenging.                                                           │
# │                                                                              │
# │ B. Biosignatures                                                             │
# │                                                                              │
# │ The most promising way to detect life on an exoplanet is by searching for    │
# │ biosignatures.                                                               │
# │                                                                              │
# │  1 What They Are: Biosignatures are chemical compounds or combinations of    │
# │    compounds in a planet's atmosphere or on its surface that are strongly    │
# │    indicative of biological activity. Examples include oxygen, methane,      │
# │    water vapor, and ozone (which is produced from oxygen). While individual  │
# │    gases can have non-biological origins, certain combinations or            │
# │    concentrations that are out of thermodynamic equilibrium could signal     │
# │    life.                                                                     │
# │  2 How We Detect Them: The primary method for searching for atmospheric      │
# │    biosignatures is transit spectroscopy. When an exoplanet transits its     │
# │    star, a tiny fraction of the star's light filters through the planet's    │
# │    atmosphere. Different atmospheric gases absorb specific wavelengths of    │
# │    light, leaving a unique "fingerprint" in the starlight. By analyzing      │
# │    these fingerprints, telescopes like the James Webb Space Telescope can    │
# │    detect the presence of potential biosignatures.                           │
# │                                                                              │
# │ C. Technosignatures (Brief Mention)                                          │
# │                                                                              │
# │ Beyond biosignatures, some scientists also look for                          │
# │ technosignatures—evidence of advanced technology. This could include         │
# │ artificial radio signals, laser emissions, or even industrial pollutants in  │
# │ an exoplanet's atmosphere that wouldn't naturally occur. This is the realm   │
# │ of SETI (Search for Extraterrestrial Intelligence).                          │
# │                                                                              │
# │ D. Key Targets                                                               │
# │                                                                              │
# │ Many exciting systems are currently being scrutinized for signs of           │
# │ habitability and life:                                                       │
# │                                                                              │
# │  • The TRAPPIST-1 system hosts seven Earth-sized planets, three of which are │
# │    in the habitable zone of their ultracool dwarf star.                      │
# │  • Proxima Centauri b, an Earth-mass planet orbiting our closest stellar     │
# │    neighbor, Proxima Centauri, also lies within its star's habitable zone.   │
# │  • K2-18b is a mini-Neptune that has shown evidence of water vapor in its    │
# │    atmosphere and potentially even liquid water clouds.                      │
# │  • And many more, with each new discovery adding to the tantalizing          │
# │    possibility of finding a living world.                                    │
# │                                                                              │
# │ VI. The Future of Exoplanet Research: A New Era of Discovery                 │
# │                                                                              │
# │ The field of exoplanet research is experiencing a golden age, with           │
# │ incredible advancements in technology and ambitious new missions on the      │
# │ horizon.                                                                     │
# │                                                                              │
# │ A. Current & Upcoming Missions                                               │
# │                                                                              │
# │  1 James Webb Space Telescope (JWST): Already operational, JWST is a         │
# │    game-changer. Its unparalleled infrared capabilities allow for            │
# │    unprecedented atmospheric characterization of exoplanets, probing for     │
# │    biosignatures and providing detailed insights into their compositions. It │
# │    can also perform some direct imaging of larger exoplanets.                │
# │  2 ARIEL (Atmospheric Remote-sensing Infrared Exoplanet Large-survey):       │
# │    Scheduled for launch by the European Space Agency, ARIEL will be          │
# │    dedicated to studying the atmospheres of hundreds of known exoplanets,    │
# │    creating a vast catalog of atmospheric data to understand planetary       │
# │    formation and evolution.                                                  │
# │  3 PLATO (PLAnetary Transits and Oscillations of stars): Another ESA         │
# │    mission, PLATO will focus on finding Earth-like planets orbiting Sun-like │
# │    stars in their habitable zones. It aims to identify and characterize a    │
# │    large number of rocky planets, including those that might be suitable for │
# │    life.                                                                     │
# │  4 Nancy Grace Roman Space Telescope: This upcoming NASA mission will        │
# │    utilize both microlensing and coronagraphy (with a powerful coronagraph   │
# │    instrument) to discover and directly image exoplanets, particularly those │
# │    at wider separations from their stars.                                    │
# │                                                                              │
# │ B. Technological Advancements                                                │
# │                                                                              │
# │ Beyond specific missions, continuous technological innovation is driving the │
# │ field forward:                                                               │
# │                                                                              │
# │  1 Next-Generation Adaptive Optics: These systems, integrated into           │
# │    ground-based telescopes, are becoming increasingly sophisticated,         │
# │    correcting for atmospheric distortions with greater precision, enabling   │
# │    sharper direct imaging of exoplanets.                                     │
# │  2 Starshades/Occulters: These are proposed external spacecraft that would   │
# │    fly in formation with a telescope, precisely blocking out the blinding    │
# │    light of a star, allowing the telescope to directly image faint,          │
# │    Earth-like planets in its glare.                                          │
# │  3 Advanced Data Analysis: The sheer volume of data from exoplanet surveys   │
# │    necessitates the use of AI and machine learning algorithms to sift        │
# │    through light curves, identify subtle signals, and characterize planetary │
# │    systems with greater efficiency and accuracy.                             │
# │                                                                              │
# │ C. Key Unanswered Questions                                                  │
# │                                                                              │
# │ Despite our progress, many fundamental questions remain:                     │
# │                                                                              │
# │  • How common is life in the universe? Is Earth a fluke, or are living       │
# │    worlds abundant?                                                          │
# │  • What are the full range of planetary system architectures? How do planets │
# │    form and evolve in different stellar environments?                        │
# │  • Can we find a true "Earth 2.0"? A planet that is not just Earth-sized and │
# │    in the habitable zone, but also demonstrably Earth-like in its            │
# │    atmospheric composition and potential for surface liquid water.           │
# │                                                                              │
# │ VII. Conclusion: Our Place in a Populated Cosmos                             │
# │                                                                              │
# │ From theoretical musings to concrete reality, the science of exoplanets has  │
# │ evolved with breathtaking speed in just a few short decades. What began as a │
# │ trickle of discoveries has become a deluge, revealing a universe far richer  │
# │ and more diverse than we ever dared to imagine.                              │
# │                                                                              │
# │ The profound impact of exoplanet research cannot be overstated. It has       │
# │ fundamentally reshaped our understanding of planetary formation,             │
# │ demonstrating that our solar system is just one design among countless       │
# │ possibilities. More importantly, it has transformed the search for life      │
# │ beyond Earth from a philosophical question into a tangible scientific        │
# │ endeavor.                                                                    │
# │                                                                              │
# │ The journey continues. With powerful new telescopes like JWST already        │
# │ delivering stunning results and ambitious future missions on the horizon,    │
# │ the next decade promises an even greater era of discovery. We are on the     │
# │ cusp of potentially answering humanity's most enduring question, and in      │
# │ doing so, forever changing our perception of our place in a populated        │
# │ cosmos. The universe, beckoning us with its countless worlds, reminds us     │
# │ that the greatest adventures lie just beyond the familiar, waiting to be     │
# │ unveiled.                                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %%
with open("./files/3-blog_summary.md", "w") as f:
    f.write(final_state["blog_summary"])

content = Path("files/3-blog_summary.md").read_text()

console.print(
    Panel(
        Markdown(content),
        title="Summary",
        border_style="#6CFCCE",
    )
)
# Out:
# ╭────────────────────────────────── Summary ───────────────────────────────────╮
# │ Exoplanet research has rapidly evolved from speculation to a robust          │
# │ scientific field, confirming thousands of planets beyond our solar system    │
# │ and fundamentally reshaping our understanding of planetary formation and     │
# │ diversity. Scientists employ ingenious indirect methods like transit         │
# │ photometry and radial velocity, alongside direct imaging and gravitational   │
# │ microlensing, to uncover a vast menagerie of worlds, from scorching Hot      │
# │ Jupiters to potentially habitable Super-Earths and rogue planets. This       │
# │ pursuit centers on identifying planets within habitable zones and detecting  │
# │ atmospheric biosignatures using advanced telescopes like JWST, which is      │
# │ revolutionizing our ability to characterize exoplanet atmospheres. This      │
# │ ongoing quest promises to fundamentally shift humanity's perception of its   │
# │ place in a diverse, potentially populated cosmos.                            │
# ╰──────────────────────────────────────────────────────────────────────────────╯
